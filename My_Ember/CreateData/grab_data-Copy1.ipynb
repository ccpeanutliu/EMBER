# %%
import numpy as np
import jsonlines
from matplotlib.pyplot import hist

# %%
num = 1
path = "/home/imccpeanut/Ember_Test/My_Ember/ember/train_features_"+ str(num) +".jsonl"

origin_feature = []
with jsonlines.open(path) as reader:
    for obj in reader:
        origin_feature.append(obj)
n = len(origin_feature)

# %%
for obj in origin_feature[0]['general'].keys():
    print(obj)
# Out:
# has_resources
# symbols
# size
# exports
# has_signature
# has_debug
# has_tls
# vsize
# imports
# has_relocations

# %%
for i in range(170000):
    if origin_feature[101000]['general']['symbols'] != 0:
        print(origin_feature[101000]['general']['symbols'])

# %%
def entropy1(labels, base=None):
    value,counts = np.unique(labels, return_counts=True)
    return entropy(counts, base=base)

# %%
pathss = "/home/imccpeanut/Ember_Test/My_Ember/feature/num_feature2.npy"

# %%
tmp = np.load(pathss)

# %%
tmp2 = np.delete(tmp,2,axis = 1)

# %%
tmp[0][2]
# Out:
# array([0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#        0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.73900e+03,
# ...

# %%
tmp2[0][0]
# Out:
# array([6.44024732e+00, 1.03510000e+04, 0.00000000e+00, 2.00000000e+01,
#        3.80000000e+01, 6.66630000e+04, 6.54097893e+00, 2.00000000e+00,
#        9.72000000e+02, 5.94000000e+02, 5.59000000e+02, 5.47000000e+02,
#        6.07000000e+02, 5.97000000e+02, 5.41000000e+02, 5.37000000e+02,
#        5.63000000e+02, 5.27000000e+02, 5.02000000e+02, 5.44000000e+02,
#        6.06000000e+02, 6.38000000e+02, 6.74000000e+02, 6.45000000e+02,
#        9.78000000e+02, 8.38000000e+02, 7.63000000e+02, 7.05000000e+02,
#        6.68000000e+02, 6.28000000e+02, 6.53000000e+02, 7.07000000e+02,
#        7.24000000e+02, 6.66000000e+02, 6.97000000e+02, 6.70000000e+02,
#        6.88000000e+02, 6.39000000e+02, 6.53000000e+02, 7.09000000e+02,
#        5.99000000e+02, 6.34000000e+02, 5.72000000e+02, 8.10000000e+02,
#        6.01000000e+02, 6.38000000e+02, 6.15000000e+02, 6.48000000e+02,
#        5.67000000e+02, 6.03000000e+02, 5.72000000e+02, 5.35000000e+02,
# ...
